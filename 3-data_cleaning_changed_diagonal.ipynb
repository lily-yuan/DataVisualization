# %%
import pandas as pd
import numpy as np
import json

# %% [markdown]
# # Change data into one mode and two mode

# %% [markdown]
# ## Load data

# %%
df = pd.read_excel("Krackhardt Web of Science Data v3.xlsx")
df.head()
# Out:
#        Article                                        Description  \
# 0  00TRDBDKSMJ  Redudant Governance Structures - Rowley, T; Be...
# 1  00TRDBDKSMJ                                                NaN
# 2  00TRDBDKSMJ                                                NaN
# 3  00TRDBDKSMJ                                                NaN
# 4  00TRDBDKSMJ                                                NaN
#
#                                   Authors  \
# 0                     Adler, PS; Kwon, SW
# 1                                Ahuja, G
# 2                    Dyer, JH; Nobeoka, K
# 3                  Inkpen, AC; Tsang, EWK
# 4  Baum, JAC; Calabrese, T; Silverman, BS
#
#                          Author Full Name  \
# 0                     Adler, PS; Kwon, SW
# 1                                Ahuja, G
# 2                    Dyer, JH; Nobeoka, K
# 3                  Inkpen, AC; Tsang, EWK
# 4  Baum, JAC; Calabrese, T; Silverman, BS
#
#                                       Document Title  \
# 0        Social capital: Prospects for a new concept
# 1  Collaboration networks, structural holes, and ...
# 2  Creating and managing a high-performance knowl...
# 3   Social capital, networks, and knowledge transfer
# 4  Don't go it alone: Alliance network compositio...
#
#                    Publication Name Publication year
# 0      ACADEMY OF MANAGEMENT REVIEW             2002
# 1  ADMINISTRATIVE SCIENCE QUARTERLY             2000
# 2      STRATEGIC MANAGEMENT JOURNAL             2000
# 3      ACADEMY OF MANAGEMENT REVIEW             2005
# 4      STRATEGIC MANAGEMENT JOURNAL             2000

# %% [markdown]
# ## Abnormal data detection

# %%
#Multi-records of the same Article-citation pair

article_citation = df.drop("Description", axis = 1).groupby(["Article", "Document Title"]).count()

multi_citation = article_citation[(article_citation["Authors"] > 1) 
                                 | (article_citation["Author Full Name"] > 1)
                                 | (article_citation["Publication Name"] > 1)
                                 | (article_citation["Publication year"] > 1)]

        
multi_citation = multi_citation.index.values.tolist()
multi_citation
# Out:
# [('00TRDBDKSMJ',
#   'Capacity Sharing Issue in an Electronic Co-Opetitive Network: A Simulative Approach'),
#  ('00TRDBDKSMJ',
#   "Collaboration partner portfolio along the growth of Chinese firms' innovation capability: configuration, evolution and pattern"),
#  ('00TRDBDKSMJ',
#   'Joint R&D projects: Experiences in the context of European technology policy'),
#  ('00TRDBDKSMJ',
#   'Network embeddedness and the exploration of novel technologies: Technological distance, betweenness centrality and density'),
#  ('00TRDBDKSMJ',
#   'With a Little Help from Our Colleagues: A Longitudinal Study of Social Networks for Innovation'),
#  ('06SPBKMCDKSN', 'The Who of Systemic Thinking'),
#  ('87DKSN', 'An equilibrium-correction model for dynamic network data'),
#  ('87DKSN', 'BLOCKMODELS - INTERPRETATION AND EVALUATION'),
#  ('87DKSN',
#   'BRINGING THE INDIVIDUAL BACK IN - A STRUCTURAL-ANALYSIS OF THE INTERNAL MARKET FOR REPUTATION IN ORGANIZATIONS'),
#  ('87DKSN', 'Cognitive inconsistencies and non-symmetric friendship'),
#  ('87DKSN',
#   'Dynamic Network Logistic Regression: A Logistic Choice Analysis of Inter- and Intra-Group Blog Citation Dynamics in the 2004 US Presidential Election'),
#  ('87DKSN',
#   "Formal and emergent predictors of coworkers' perceptual congruence on an organization's social structure"),
#  ('87DKSN',
#   'Just Like a Woman? Effects of Gender-Biased Perceptions of Friendship Network Brokerage on Attributions and Performance'),
#  ('87DKSN',
#   'LOGISTIC NETWORK REGRESSION FOR SCALABLE ANALYSIS OF NETWORKS WITH JOINT EDGE/VERTEX DYNAMICS'),
#  ('87DKSN',
#   'Network inference, error, and informant (in)accuracy: a Bayesian approach'),
#  ('87DKSN', 'PERMUTATION MODELS FOR RELATIONAL DATA'),
#  ('87DKSN',
#   'Social Network Analysis: Understanding the Role of Context in Small Groups and Organizations'),
#  ('87DKSN', 'Social network analysis: A methodological introduction'),
#  ('87DKSN',
#   'THE INTERPERSONAL STRUCTURE OF DECISION-MAKING - A SOCIAL-COMPARISON APPROACH TO ORGANIZATIONAL CHOICE'),
#  ('87DKSN',
#   'Testing multitheoretical, multilevel hypotheses about organizational networks: An analytic framework and empirical example'),
#  ('87DKSN', 'UNDERSTANDING GROUPS FROM A NETWORK PERSPECTIVE'),
#  ('87DKSN',
#   'Whether close or far: Social distance effects on perceived balance in friendship networks'),
#  ('88DKSN',
#   'Win Friends and Influence People Relationships as Conduits of Organizational Culture in Temporary Placement Agencies'),
#  ('92DKNO:SFA',
#   "A Social Capital Perspective on IT Professionals' Work Behavior and Attitude")]

# %%
#Multi-description of the same article

article_description = df.dropna(subset=["Description"])[["Article", "Description"]].groupby(["Article"]).count()

multi_description = article_description[article_description["Description"] > 1]
        
multi_description = multi_description.index.values.tolist()
multi_description
# Out:
# ['87DKSN']

# %% [markdown]
# ## Two mode

# %%
rows = df['Document Title'].unique()
cols = df['Article'].unique()
two_mode = pd.DataFrame(data=np.zeros((rows.shape[0],cols.shape[0]),dtype=int),index=rows,columns=cols)

row_dict = dict(zip(rows,range(rows.shape[0])))
col_dict = dict(zip(cols,range(cols.shape[0])))

# %%
for ind in df.index:
    article_name = df['Document Title'][ind]
    doc_name = df['Article'][ind]
    two_mode.at[article_name, doc_name] += 1
    
two_mode.head()
# Out:
#                                                     00TRDBDKSMJ  92DKNO:SFA  \
# Social capital: Prospects for a new concept                   1           0
# Collaboration networks, structural holes, and i...            1           1
# Creating and managing a high-performance knowle...            1           0
# Social capital, networks, and knowledge transfer              1           1
# Don't go it alone: Alliance network composition...            1           0
#
#                                                     90DKASQ  88DKSRNSPQ  \
# Social capital: Prospects for a new concept               0           1
# Collaboration networks, structural holes, and i...        0           0
# Creating and managing a high-performance knowle...        0           0
# Social capital, networks, and knowledge transfer          0           0
# Don't go it alone: Alliance network composition...        0           0
#
#                                                     88DKSN   93DKJRHHBR  \
# Social capital: Prospects for a new concept              0            1
# Collaboration networks, structural holes, and i...       0            0
# Creating and managing a high-performance knowle...       0            0
# Social capital, networks, and knowledge transfer         0            0
# Don't go it alone: Alliance network composition...       0            0
#
#                                                     87DKSN  94MKDKAMJ  \
# Social capital: Prospects for a new concept              0          0
# Collaboration networks, structural holes, and i...       0          0
# Creating and managing a high-performance knowle...       0          0
# Social capital, networks, and knowledge transfer         0          0
# Don't go it alone: Alliance network composition...       0          0
#
#                                                     07DDDKTSP  06SPBKMCDKSN  \
# Social capital: Prospects for a new concept                 0             0
# Collaboration networks, structural holes, and i...          0             0
# Creating and managing a high-performance knowle...          0             0
# Social capital, networks, and knowledge transfer            0             0
# Don't go it alone: Alliance network composition...          0             0
#
#                                                     ...  96JBCMDKGD  \
# Social capital: Prospects for a new concept         ...           0
# Collaboration networks, structural holes, and i...  ...           0
# Creating and managing a high-performance knowle...  ...           0
# Social capital, networks, and knowledge transfer    ...           0
# Don't go it alone: Alliance network composition...  ...           0
#
#                                                     15PPAPJLDKEMJ  \
# Social capital: Prospects for a new concept                     0
# Collaboration networks, structural holes, and i...              0
# Creating and managing a high-performance knowle...              0
# Social capital, networks, and knowledge transfer                0
# Don't go it alone: Alliance network composition...              0
#
#                                                     14KGDKLWSMR  95DKASQ  \
# Social capital: Prospects for a new concept                   0        0
# Collaboration networks, structural holes, and i...            0        0
# Creating and managing a high-performance knowle...            0        0
# Social capital, networks, and knowledge transfer              0        0
# Don't go it alone: Alliance network composition...            0        0
#
#                                                     77LLDKHO  14PPJLDKPEC  \
# Social capital: Prospects for a new concept                0            0
# Collaboration networks, structural holes, and i...         0            0
# Creating and managing a high-performance knowle...         0            0
# Social capital, networks, and knowledge transfer           0            0
# Don't go it alone: Alliance network composition...         0            0
#
#                                                     14DKCPOSN  07DKTSJRSSSASS  \
# Social capital: Prospects for a new concept                 0               0
# Collaboration networks, structural holes, and i...          0               0
# Creating and managing a high-performance knowle...          0               0
# Social capital, networks, and knowledge transfer            0               0
# Don't go it alone: Alliance network composition...          0               0
#
#                                                     02NEFDKSN  98PHFHDKCA
# Social capital: Prospects for a new concept                 0           0
# Collaboration networks, structural holes, and i...          0           0
# Creating and managing a high-performance knowle...          0           0
# Social capital, networks, and knowledge transfer            0           0
# Don't go it alone: Alliance network composition...          0           0
#
# [5 rows x 55 columns]

# %% [markdown]
# ## One mode

# %%
#using dot product of two-mode to get the number of co-citation

A = np.array(two_mode)
G = np.dot(A.T, A)
one_mode = pd.DataFrame(data=G, index=cols, columns=cols)

for articles in one_mode.columns.values.tolist():
    one_mode.loc[articles, articles] = np.sum(df["Article"] == articles)
    
one_mode.head()
# Out:
#              00TRDBDKSMJ  92DKNO:SFA  90DKASQ  88DKSRNSPQ  88DKSN  \
# 00TRDBDKSMJ          846          74       24          11       5
# 92DKNO:SFA            74         628       50          30      28
# 90DKASQ               24          50      583          40      33
# 88DKSRNSPQ            11          30       40         420      20
# 88DKSN                 5          28       33          20     438
#
#               93DKJRHHBR  87DKSN  94MKDKAMJ  07DDDKTSP  06SPBKMCDKSN  ...  \
# 00TRDBDKSMJ            6      10         14          2             2  ...
# 92DKNO:SFA            32      43         31          7             3  ...
# 90DKASQ               40     100         59          6             2  ...
# 88DKSRNSPQ            28      29         17          9             5  ...
# 88DKSN                12     144         25        102             9  ...
#
#              96JBCMDKGD  15PPAPJLDKEMJ  14KGDKLWSMR  95DKASQ  77LLDKHO  \
# 00TRDBDKSMJ           0              0            1        2         0
# 92DKNO:SFA            0              0            0        0         0
# 90DKASQ               0              0            0        0         0
# 88DKSRNSPQ            0              0            0        0         0
# 88DKSN                0              0            0        0         0
#
#              14PPJLDKPEC  14DKCPOSN  07DKTSJRSSSASS  02NEFDKSN  98PHFHDKCA
# 00TRDBDKSMJ            0          0               0          0           0
# 92DKNO:SFA             0          0               0          0           0
# 90DKASQ                0          0               0          0           0
# 88DKSRNSPQ             0          0               0          0           0
# 88DKSN                 0          0               0          1           1
#
# [5 rows x 55 columns]

# %% [markdown]
# ## Output the data in csv format

# %%
two_mode.to_csv("two_mode.csv")
one_mode.to_csv("one_mode.csv")

# %% [markdown]
# # Create Json Files

# %%
#Change one-mode dataframe into source-target list

src_dst = pd.DataFrame(columns=['source', 'target', 'value'])

for i in range(len(one_mode)):
    for j in range(i + 1, len(one_mode)):
        src_dst = src_dst.append([{'source': one_mode.columns.values[i], 
                                   'target': one_mode.columns.values[j],
                                   'value': one_mode.iloc[i, j]}], ignore_index=True, sort=False)
        
src_dst[0: 5]
# Out:
#         source       target value
# 0  00TRDBDKSMJ   92DKNO:SFA    74
# 1  00TRDBDKSMJ      90DKASQ    24
# 2  00TRDBDKSMJ   88DKSRNSPQ    11
# 3  00TRDBDKSMJ       88DKSN     5
# 4  00TRDBDKSMJ   93DKJRHHBR     6

# %% [markdown]
# ## Link List

# %%
#Create link list

links_list = []

indexes = pd.Index(src_dst['source']
                   .append(src_dst['target'])
                   .reset_index(drop=True).unique())

for index, link in src_dst.iterrows():
    record = {"source": indexes.get_loc(link['source']),
              "target": indexes.get_loc(link['target']),
              "value": link['value']}
    links_list.append(record)
    
links_list[0: 10]
# Out:
# [{'source': 0, 'target': 1, 'value': 74},
#  {'source': 0, 'target': 2, 'value': 24},
#  {'source': 0, 'target': 3, 'value': 11},
#  {'source': 0, 'target': 4, 'value': 5},
#  {'source': 0, 'target': 5, 'value': 6},
#  {'source': 0, 'target': 6, 'value': 10},
#  {'source': 0, 'target': 7, 'value': 14},
#  {'source': 0, 'target': 8, 'value': 2},
#  {'source': 0, 'target': 9, 'value': 2},
#  {'source': 0, 'target': 10, 'value': 19}]

# %% [markdown]
# ## Node List

# %%
nodes_list = []

#article_description = df[["Article", "Description"]].groupby('Article').nth(0).reset_index()

for i in range(len(one_mode)):
    name = one_mode.columns.values.tolist()[i]
    year = int(one_mode.columns.values.tolist()[i][0: 2])
    year = (1900 + year) if year > 20 else (2000 + year)
    nodes_list.append({"name": name, 
                        "group": year,
                        "size": int(one_mode.iloc[i, i]),
                        "meta_node": df[df["Article"] == name].iloc[0, ]["Description"]})
    
nodes_list[0: 5]
# Out:
# [{'name': '00TRDBDKSMJ',
#   'group': 2000,
#   'size': 846,
#   'meta_node': 'Redudant Governance Structures - Rowley, T; Behrens, D; Krackhardt, D; Strategic Management Journal - March 2000'},
#  {'name': '92DKNO:SFA',
#   'group': 1992,
#   'size': 628,
#   'meta_node': 'The Strength of Strong Ties - Krackhardt, D - Networks & Organizations: Structure, Form, & Action - 1992'},
#  {'name': '90DKASQ',
#   'group': 1990,
#   'size': 583,
#   'meta_node': 'Assessing the Political Landscape - Krackhardt, D; Administrative Science Quarterly - June 1992'},
#  {'name': '88DKSRNSPQ',
#   'group': 1988,
#   'size': 420,
#   'meta_node': 'Informal Network and Organizational Crises - Krackhardt, D; Stern, RN; Social Psychology Quarterly - June 1988'},
#  {'name': '88DKSN',
#   'group': 1988,
#   'size': 438,
#   'meta_node': 'Predicting with Networks - Krackhardt, D; Social Networks - Dec. 1988'}]

# %% [markdown]
# ## Output to files

# %%
json_prep = {"links":links_list, "nodes":nodes_list}
json_dump = json.dumps(json_prep, indent=1, sort_keys=True)

# %%
filename_out = 'link_node.json'
json_out = open(filename_out,'w')
json_out.write(json_dump)
json_out.close()
